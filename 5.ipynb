# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivaShirsath/ImageProcessing/blob/master/5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# Load the image dataset
img = cv2.imread("image.jpg")

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Apply edge detection algorithms to image
sobel = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=5)

canny = cv2.Canny(gray, 100, 200)

laplacian = cv2.Laplacian(gray, cv2.CV_64F)

# %%
# Display the original and edge detected image for each algorithm
cv2_imshow(img)
cv2_imshow(sobel)
cv2_imshow(canny)
cv2_imshow(laplacian)
# Out:
# <PIL.Image.Image image mode=RGB size=750x555 at 0x7FC93039FDF0>
# <PIL.Image.Image image mode=L size=750x555 at 0x7FC8FAB8EDF0>
# <PIL.Image.Image image mode=L size=750x555 at 0x7FC8FAB8EE20>
# <PIL.Image.Image image mode=L size=750x555 at 0x7FC8FAB8EDF0>
